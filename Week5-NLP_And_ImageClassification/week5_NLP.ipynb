# %%
import pandas as pd
import numpy as np
import re
import nltk
import collections

from nltk.tokenize import word_tokenize
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
#nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('punkt')
from nltk.probability import FreqDist
nltk.download('averaged_perceptron_tagger')

from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics

# %matplotlib inline
# Out:
# [nltk_data] Downloading package wordnet to c:\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to c:\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     c:\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
dataset = pd.read_csv('CyberCrimeArticles-3.csv')
dataset.head()
# Out:
#                                    Image_Description  \
# 0  Rapid delivery's rapid rise has led to tension...
# 1  Start-up conference Step in Dubai Internet City.
# 2  Meta CEO Mark Zuckerberg said the company's co...
# 3                            Carolyn Kaster/AP Photo
# 4  Choosing a green pension could be better for t...
#
#                                                 Link  \
# 0  https://static.euronews.com/articles/stories/0...
# 1  https://static.euronews.com/articles/stories/0...
# 2  https://static.euronews.com/articles/stories/0...
# 3  https://static.euronews.com/articles/stories/0...
# 4  https://static.euronews.com/articles/stories/0...
#
#                                        Article_Title  \
# 0  Dutch cities temporarily banned 10-minute deli...
# 1  How Dubai Internet City is becoming a hub for ...
# 2  Ahoy, Metamates! Meta continues rebranding eff...
# 3  Ahoy, Metamates! Meta continues rebranding eff...
# 4  Green pensions could be the ‘most powerful wea...
#
#                                          Article_URL  \
# 0  https://www.euronews.com/next/2022/02/24/dutch...
# 1  https://www.euronews.com/next/2022/02/23/how-d...
# 2  https://www.euronews.com/next/2022/02/16/ahoy-...
# 3  https://www.euronews.com/next/2022/02/16/ahoy-...
# 4  https://www.euronews.com/green/2022/02/15/gree...
#
#                                         Article_Text
# 0  ['Noise, reckless cycling and blacked-out wind...
# 1  ['Khazna, one of the largest data centre infra...
# 2  ["Employees at Facebook's parent company Meta ...
# 3  ["Employees at Facebook's parent company Meta ...
# 4  ['Switching to a sustainable pension could be ...

# %%
dataset["Article_URL"][0]
# Out:
# 'https://www.euronews.com/next/2022/02/24/dutch-cities-temporarily-banned-10-minute-delivery-dark-stores-then-one-company-threatened'

# %%
dataset["Article_Text"][0]
# Out:
# '[\'Noise, reckless cycling and blacked-out windows are some of the reasons rapid delivery services like Gorillas, Getir, Flink and Zapp have clashed with residents in cities across the Netherlands.\', \'Now, one rapid delivery service has accused Dutch city officials of breaking EU law after they imposed a year-long ban on new "dark stores" - the virtual supermarket warehouses that allow high-speed delivery of groceries and other household goods.\', \'Last month, city councillors in Amsterdam and Rotterdam voted to freeze development of dark stores following complaints prompted by the speed of growth of the rapid delivery services during the pandemic.\', \'Now, other Dutch cities are set to follow their example, with moves to restrict the delivery apps underway in 23 other municipalities, according to the Dutch newspaper NRC.\', \'Berlin-based Flink told Euronews Next it was "evaluating all options, including legal action" in response to the freeze.\', \'Amsterdam and Rotterdam\\\'s "restrictions on the freedom of services must meet the conditions of non-discrimination, necessity, and proportionality, which they do not in our opinion," the company said.\', \'Two years ago, there were no rapid delivery services in the Netherlands. German startup Gorillas entered the Dutch market in December 2020. It was followed by competitors Getir, Flink and Zapp in 2021.\', \'Now, the four companies compete with each other to deliver food and other items to customers within 10 minutes, ballooning the number of rapid delivery customers from 200,000 in early 2021 to around 700,000 now, according to an analysis by Kantar.\', "Dark stores are crucial to their business model. In an industry where speed is king, putting the distribution centres in residential areas, closer to their customers, provides a clear advantage. It\'s also at the heart of the problem.", \'"From the moment the first dark stores settled in busy residential areas or shopping streets in the spring of 2021, complaints by residents and surrounding shop keepers started to reach us," Tristan van Rijn, spokesperson for Rotterdam politician Roos Vermeij, told Euronews Next.\', \'"We try to prevent empty or vacant shops to keep shopping streets lively and to create a natural \\\'flow\\\' from shop to shop. A dark store with blinded windows, causing unsafe traffic and nuisance, does not contribute to that," he said.\', "From the city\'s perspective, the one-year freeze is a way to slow development and allow regulations to catch up, he said.", \'"We will use this period to come up with a new set of rules and a new zoning plan to regulate where dark stores may settle, and where they may not. This freeze does not focus on the concept of dark stores, but on their locations".\', \'The basic issue, according to van Rijn, is that dark stores exploit a "blind spot" in urban planning rules.\', \'A dark store acts as a small-scale distribution centre, generating traffic and other activity around it. But in Rotterdam, rapid delivery firms were able to set up dark stores in areas zoned for retail uses like shops and supermarkets.\', \'A post shared by Stop Dark Stores (@stopdarkstoreswoonwijk)\', \'"In our view, this is indeed a case of legislation not keeping up with new market concepts," van Rijn admitted.\', \'Before opening a new store, a supermarket chain must apply for a permit and agree to work only during fixed operating hours, he said. Dark stores, on the other hand, are able to run 24/7. They can pop up without permits or restrictions.\', \'This has fuelled conflict between the rapid delivery companies and their potential customers, and even led residents of one street in Amsterdam to start a petition against a dark store that opened in the garage of an apartment building.\', "For their part, the companies contacted by Euronews Next acknowledge that the speed of the industry\'s growth has caused some friction.", \'"Our customers are very satisfied with Flink’s services. Demand is incre ...

# %%
def lemmatizeList( li ):
    lemmatizer = WordNetLemmatizer()
    res = []
    for theWord, theTag in nltk.pos_tag(li):
        if theTag.startswith("VB"):
            res.append( lemmatizer.lemmatize(theWord, pos = 'v') )
        elif theTag.startswith("NN"):
            res.append( lemmatizer.lemmatize(theWord, pos = 'n') )
        elif theTag.startswith("RB"):
            res.append( lemmatizer.lemmatize(theWord, pos = 'r') )
        elif theTag.startswith("JJ"):
            res.append( lemmatizer.lemmatize(theWord, pos = 'a') )
    return res

# %%
def getNouns( sent ): 
    sent = [word for word in word_tokenize(sent.lower())]
    res = []
    for theWord, theTag in nltk.pos_tag(sent):
        if theTag.startswith("NN"):
            res.append(theWord)
    return " ".join(res)

# %%
stop_words = set(stopwords.words('english'))
sent = dataset.loc[0,'Article_Text']

# Use a regex to catch all single letter words, html tags or other non-alphanumeric characters then substitute them with a space
cleaned = re.sub(r"(?:(?:^|\s+)[a-zA-Z]\s+)|<.*?>|\W", ' ', sent)

# Tokenize the sentence using word_tokenize method
tokenized_sent = [word for word in word_tokenize(cleaned.lower())]

# lemmatize sentence then append to the list containing lemmatized reviews without punctuation 
lemmatized_words = lemmatizeList( tokenized_sent )

# remove stopwords then append to the list containing lemmatized reviews without punctuation or stopwords
lemmaNoStop = [word for word in lemmatized_words if word not in stop_words]
tem = [" ".join(lemmaNoStop) ]
#tem[0] = getNouns(tem[0])
print(tem)
# Out:
# ['noise reckless cycling black window reason rapid delivery service gorilla getir flink zapp clash resident city netherlands rapid delivery service accuse dutch city official break eu law impose year long ban new dark store virtual supermarket warehouse allow high speed delivery grocery household good last month city councillor amsterdam rotterdam vote freeze development dark store follow complaint prompt speed growth rapid delivery service pandemic dutch city set follow example move restrict delivery apps underway municipality accord dutch newspaper nrc berlin base flink tell euronews evaluate option include legal action response freeze amsterdam rotterdam restriction freedom service meet condition non discrimination necessity proportionality opinion company say year ago rapid delivery service netherlands german startup gorilla enter dutch market december follow competitor getir flink zapp company compete deliver food item customer minute balloon number rapid delivery customer early accord analysis kantar dark store crucial business model industry speed king put distribution centre residential area closer customer provide clear advantage also heart problem moment first dark store settle busy residential area shop street spring complaint resident surround shop keeper start reach tristan van rijn spokesperson rotterdam politician roos vermeij tell euronews try prevent empty vacant shop keep shop street lively create natural flow shop shop dark store blinded window cause unsafe traffic nuisance contribute say city perspective year freeze way slow development allow regulation catch say use period come new set rule new zone plan regulate dark store settle freeze focus concept dark store location basic issue accord van rijn dark store exploit spot urban planning rule dark store act small scale distribution centre generate traffic activity rotterdam rapid delivery firm able set dark store area zone retail us shop supermarkets post share stop dark store stopdarkstoreswoonwijk view indeed case legislation keep new market concept van rijn admit open new store supermarket chain apply permit agree work fix operating hour say dark store hand able run pop permit restriction fuel conflict rapid delivery company potential customer even lead resident street amsterdam start petition dark store open garage apartment building part company contact euronews acknowledge speed industry growth cause friction customer satisfied flink service demand increase rapidly week flink spokesperson lindsey davidson tell euronews time notice increase dissatisfaction neighbourhood grow incredibly fast year growth naturally go hand hand growing pain say grow pain davidson say flink oppose freeze impose amsterdam rotterdam municipality drastic decision take happen municipality amsterdam rotterdam municipality alderman never react invitation meet say accord van rijn company willing speak rotterdam official see amsterdam rotterdam response extreme unconsidered reaction believe decision municipality unlawful violate eu law restriction freedom service meet condition non discrimination necessity proportionality opinion davidson say response van rijn tell euronews temporary freeze well city right impose freeze lawful instrument prepare new zone plan agree city council instrument use many time say rapid delivery company affect freeze tell euronews also aware potential issue neighbour netherlands carefully pick location store deliver cent electric vehicle create nuisance turkey base getir say continue adopt constructive position time happy discuss municipality thing improve gorilla say statement company say welcome opportunity speak municipality netherlands order develop new policy dark store together']

# %%
tfidf_vectorizer = TfidfVectorizer(min_df = 0, max_df = 1, ngram_range=(1,3))

vect = tfidf_vectorizer.fit_transform(tem)

# %%
feature_array = np.array(tfidf_vectorizer.get_feature_names())
feature_array
# Out:
# array(['able', 'able run', 'able run pop', ..., 'zone plan regulate',
#        'zone retail', 'zone retail us'], dtype='<U40')

# %%
tfidf_sorting = np.argsort(vect.toarray()).flatten()[::-1]

n = 15
top_n = feature_array[tfidf_sorting][:n]
top_n
# Out:
# array(['store', 'dark', 'dark store', 'say', 'delivery', 'rotterdam',
#        'freeze', 'rapid', 'rapid delivery', 'new', 'municipality', 'shop',
#        'service', 'company', 'city'], dtype='<U40')

# %%
getNouns(" ".join(top_n))
# Out:
# 'store dark store delivery rotterdam freeze delivery municipality shop service company city'

# %%
topRel = []

# initializing a set containing english stopwords
stop_words = set(stopwords.words('english'))


for i in range(0, len(dataset['Article_Text'])):
    sent = dataset.loc[i,'Article_Text']
    
    # Use a regex to catch all single letter words, html tags or other non-alphanumeric characters then substitute them with a space
    cleaned = re.sub(r"(?:(?:^|\s+)[a-zA-Z]\s+)|<.*?>|\W", ' ', sent)
    
    # Tokenize the sentence using word_tokenize method
    tokenized_sent = [word for word in word_tokenize(cleaned.lower())]

    # lemmatize sentence then append to the list containing lemmatized reviews without punctuation 
    lemmatized_words = lemmatizeList( tokenized_sent )

    # remove stopwords then append to the list containing lemmatized reviews without punctuation or stopwords
    lemmaNoStop = [word for word in lemmatized_words if word not in stop_words]
    tem = [ " ".join(lemmaNoStop)]
    #cleanedData.append( tem[0])
    tfidf_vectorizer = TfidfVectorizer(min_df = 0, max_df = 1, ngram_range=(1,3))
    if(len(tem[0].strip())):
        vect = tfidf_vectorizer.fit_transform(tem)
        feature_array = np.array(tfidf_vectorizer.get_feature_names())
        tfidf_sorting = np.argsort(vect.toarray()).flatten()[::-1]

        n = 15
        top_n = feature_array[tfidf_sorting][:n]
        top_n = [w for w in word_tokenize(getNouns(" ".join(top_n)))]
        top_n = set(top_n)
        topRel.append(list(top_n))
    else:
        topRel.append("N/A")

# %%
topRel
# Out:
# [['company',
#   'shop',
#   'freeze',
#   'rotterdam',
#   'dark',
#   'store',
#   'delivery',
#   'municipality',
#   'service',
#   'city'],
#  ['khazna',
#   'centre',
#   'internet',
#   'data',
#   'increase',
#   'dubai',
#   'support',
#   'strategy',
#   'city'],
#  ['employee',
#   'company',
#   'privacy',
#   'use',
#   'meta',
#   'tuesday',
#   'facebook',
#   'zuckerberg',
#   'lawsuit',
#   'value'],
#  ['employee',
#   'company',
#   'privacy',
#   'use',
#   'meta',
#   'tuesday',
#   'facebook',
#   'zuckerberg',
#   'lawsuit',
#   'value'],
#  ['company', 'invest', 'use', 'matter', 'pension', 'money', 'study', 'carbon'],
#  ['company',
#   'shop',
#   'freeze',
#   'rotterdam',
#   'dark',
#   'store',
#   'delivery',
#   'municipality',
#   'service',
#   'city'],
#  ['ikea', 'release', 'streetwear', 'post', 'share', 'greggs'],
#  ['ikea', 'release', 'streetwear', 'post', 'share', 'greggs'],
#  ['woman',
#   'entrepreneur',
#   'founder',
#   'fashion',
#   'male',
#   'business',
#   'support',
#   'year'],
#  ['woman',
#   'entrepreneur',
#   'founder',
#   'fashion',
#   'male',
#   'business',
#   'support',
#   'year'],
#  ['woman',
#   'entrepreneur',
#   'founder',
#   'fashion',
#   'male',
#   'business',
#   'support',
#   'year'],
#  ['company',
#   'newclimate',
#   'emission',
#   'net',
#   'climate',
#   'claim',
#   'institute',
#   'action',
#   'report',
#   'target',
#   'carbon'],
#  ['company',
#   'newclimate',
#   'emission',
#   'net',
#   'climate',
#   'claim',
#   'institute',
#   'action',
#   'report',
#   'target',
#   'carbon'],
#  ['company',
#   'newclimate',
#   'emission',
#   'net',
#   'climate',
#   'claim',
#   'institute',
#   'action',
#   'report',
#   'target',
#   'carbon'],
#  ['jre', 'ek', 'joe', 'podcast', 'week', 'rogan'],
#  ['company',
#   'twitter',
#   'user',
#   'misinformation',
#   'result',
#   'meta',
#   'medium',
#   'call',
#   'facebook',
#   'platform'],
#  ['project',
#   'world',
#   'china',
#   'qingdao',
#   'summit',
#   'increase',
#   'business',
#   'year',
#   'city',
#   'industry',
#   'cent'],
#  ['project',
#   'world',
#   'china',
#   'qingdao',
#   'summit',
#   'increase',
#   'business',
#   'year',
#   'city',
#   'industry',
#   'cent'],
#  ['content',
#   'misinformation',
#   'joe',
#   'podcast',
#   'platform',
#   'policy',
#   'rogan'],
#  ['content',
#   'misinformation',
#   'joe',
#   'podcast',
#   'platform',
#   'policy',
#   'rogan'],
#  ['company',
#   'enel',
#   'president',
#   'russia',
#   'government',
#   'firm',
#   'meeting',
#   'eni'],
#  ['company',
#   'technology',
#   'world',
#   'country',
#   'dubai',
#   'launch',
#   'business',
#   'time',
#   'year',
#   'platform'],
#  ['create', 'company', 'shop', 'help', 'retailer', 'brand', 'business'],
#  ['create', 'company', 'shop', 'help', 'retailer', 'brand', 'business'],
#  ['aircraft',
#   'airbus',
#   'a321neo',
#   'aisle',
#   'airline',
#   'contract',
#   'a350',
#   'order',
#   'qatar',
#   'state'],
#  ['company',
#   'video',
#   'activision',
#   'regulator',
#   'game',
#   'discrimination',
#   'tech',
#   'deal',
#   'acquisition'],
#  ['select',
#   'technology',
#   'field',
#   'people',
#   'science',
#   'council',
#   'life',
#   'vinfuture'],
#  ['day',
#   'company',
#   'trial',
#   'productivity',
#   'work',
#   'pilot',
#   'worker',
#   'time',
#   'hour',
#   'week',
#   'cent'],
#  ['day',
#   'company',
#   'trial',
#   'productivity',
#   'work',
#   'pilot',
#   'worker',
#   'time',
#   'hour',
#   'week',
#   'cent'],
#  ['employee',
#   'company',
#   'office',
#   'plan',
#   'vaccinate',
#   'spokesperson',
#   'meta',
#   'omicron',
#   'delay',
#   'work'],
#  ['world',
#   'opportunity',
#   'hotel',
#   'provide',
#   'dubai',
#   'government',
#   'business',
#   'expo',
#   'keffer'],
#  ['album',
#   'bowie',
#   'warner',
#   'music',
#   'choose',
#   'catalogue',
#   'deal',
#   'david',
#   'caretaker',
#   'estate',
#   'co',
#   'wcm',
#   'song'],
#  ['album',
#   'bowie',
#   'warner',
#   'music',
#   'choose',
#   'catalogue',
#   'deal',
#   'david',
#   'caretaker',
#   'estate',
#   'co',
#   'wcm',
#   'song'],
#  ['shareholder',
#   'growth',
#   'apple',
#   'stock',
#   'market',
#   'cash',
#   'investor',
#   'product',
#   'year',
#   'service',
#   'sale'],
#  ['supply',
#   'motor',
#   'hyundai',
#   'demand',
#   'vehicle',
#   'target',
#   'cent',
#   'shortage',
#   'year',
#   'sale',
#   'chip'],
#  ['company',
#   'sustainability',
#   'claim',
#   'consumer',
#   'brand',
#   'business',
#   'product',
#   'evidence',
#   'shopper'],
#  ['company',
#   'sustainability',
#   'claim',
#   'consumer',
#   'brand',
#   'business',
#   'product',
#   'evidence',
#   'shopper'],
#  ['company',
#   'sustainability',
#   'claim',
#   'consumer',
#   'brand',
#   'business',
#   'product',
#   'evidence',
#   'shopper'],
#  ['family', 'travel', 'country', 'visit', 'year', 'week', 'half'],
#  ['property',
#   'home',
#   'people',
#   'market',
#   'think',
#   'estate',
#   'year',
#   'decorate',
#   'work'],
#  ['property',
#   'home',
#   'people',
#   'market',
#   'think',
#   'estate',
#   'year',
#   'decorate',
#   'work'],
#  ['company',
#   'world',
#   'range',
#   'market',
#   'marketing',
#   'hisense',
#   'brand',
#   'business',
#   'consumer',
#   'awareness',
#   'sale'],
#  ['company',
#   'world',
#   'range',
#   'market',
#   'marketing',
#   'hisense',
#   'brand',
#   'business',
#   'consumer',
#   'awareness',
#   'sale'],
#  ['company',
#   'world',
#   'range',
#   'market',
#   'marketing',
#   'hisense',
#   'brand',
#   'business',
#   'consumer',
#   'awareness',
#   'sale'],
#  ['company',
#   'world',
#   'range',
#   'market',
#   'marketing',
#   'hisense',
#   'brand',
#   'business',
#   'consumer',
#   'awareness',
#   'sale'],
#  ['sofia',
#   'serve',
#   'area',
#   'park',
#   'vitosha',
#   'meat',
#   'check',
#   'city',
#   'stay',
#   'spot'],
#  ['sofia',
#   'serve',
#   'area',
#   'park',
#   'vitosha',
#   'meat',
#   'check',
#   'city',
#   'stay',
#   'spot'],
#  ['sofia',
#   'serve',
#   'area',
#   'park',
#   'vitosha',
#   'meat',
#   'check',
#   'city',
#   'stay',
#   'spot'],
#  ['sofia',
#   'serve',
#   'area',
#   'park',
#   'vitosha',
#   'meat',
#   'check',
#   'city',
#   'stay',
#   'spot'],
#  ['sofia',
#   'serve',
#   'area',
#   'park',
#   'vitosha',
#   'meat',
#   'check',
#   'city',
#   'stay',
#   'spot'],
#  ['plan',
#   'world',
#   'position',
#   'stage',
#   'development',
#   'nation',
#   'government',
#   'function',
#   'university',
#   'state'],
#  ['plan',
#   'world',
#   'position',
#   'stage',
#   'development',
#   'nation',
#   'government',
#   'function',
#   'university',
#   'state'],
#  ['sign',
#   'company',
#   'investment',
#   'country',
#   'investor',
#   'government',
#   'forum',
#   'group',
#   'energy'],
#  ['sign',
#   'company',
#   'investment',
#   'country',
#   'investor',
#   'government',
#   'forum',
#   'group',
#   'energy'],
#  ['sign',
#   'company',
#   'investment',
#   'country',
#   'investor',
#   'government',
#   'forum',
#   'group',
#   'energy'],
#  ['technology',
#   'sector',
#   'today',
#   'government',
#   'move',
#   'robot',
#   'year',
#   'platform',
#   'service',
#   'development'],
#  ['company',
#   'country',
#   'investment',
#   'investor',
#   'government',
#   'support',
#   'year',
#   'kazakhstan',
#   'industry'],
#  ['company',
#   'country',
#   'investment',
#   'investor',
#   'government',
#   'support',
#   'year',
#   'kazakhstan',
#   'industry'],
#  ['company',
#   'country',
#   'investment',
#   'investor',
#   'government',
#   'support',
#   'year',
#   'kazakhstan',
#   'industry'],
#  ['company',
#   'country',
#   'investment',
#   'investor',
#   'government',
#   'support',
#   'year',
#   'kazakhstan',
#   'industry'],
#  ['company',
#   'plan',
#   'growth',
#   'month',
#   'stock',
#   'reddit',
#   'year',
#   'post',
#   'share',
#   'announce'],
#  ['company',
#   'chanel',
#   'woman',
#   'luxury',
#   'fashion',
#   'brand',
#   'consumer',
#   'india',
#   'ceo',
#   'industry'],
#  ['company',
#   'chanel',
#   'woman',
#   'luxury',
#   'fashion',
#   'brand',
#   'consumer',
#   'india',
#   'ceo',
#   'industry'],
#  ['company',
#   'chanel',
#   'woman',
#   'luxury',
#   'fashion',
#   'brand',
#   'consumer',
#   'india',
#   'ceo',
#   'industry'],
#  ['technology',
#   'sector',
#   'today',
#   'government',
#   'move',
#   'robot',
#   'year',
#   'platform',
#   'service',
#   'development'],
#  ['world',
#   'horizon',
#   'vision',
#   'creator',
#   'vr',
#   'meta',
#   'people',
#   'develop',
#   'year'],
#  ['company',
#   'world',
#   'use',
#   'palantir',
#   'way',
#   'data',
#   'deal',
#   'year',
#   'gharbi',
#   'platform',
#   'partnership'],
#  ['company',
#   'world',
#   'use',
#   'palantir',
#   'way',
#   'data',
#   'deal',
#   'year',
#   'gharbi',
#   'platform',
#   'partnership'],
#  ['charge',
#   'confirm',
#   'proposal',
#   'delivery',
#   'retailer',
#   'law',
#   'meeting',
#   'place',
#   'book',
#   'bookstore'],
#  ['charge',
#   'confirm',
#   'proposal',
#   'delivery',
#   'retailer',
#   'law',
#   'meeting',
#   'place',
#   'book',
#   'bookstore'],
#  ['charge',
#   'confirm',
#   'proposal',
#   'delivery',
#   'retailer',
#   'law',
#   'meeting',
#   'place',
#   'book',
#   'bookstore'],
#  ['company',
#   'seller',
#   'profit',
#   'report',
#   'product',
#   'fee',
#   'marketplace',
#   'service',
#   'sale',
#   'cent'],
#  ['company',
#   'seller',
#   'profit',
#   'report',
#   'product',
#   'fee',
#   'marketplace',
#   'service',
#   'sale',
#   'cent'],
#  ['company',
#   'seller',
#   'profit',
#   'report',
#   'product',
#   'fee',
#   'marketplace',
#   'service',
#   'sale',
#   'cent'],
#  ['world',
#   'game',
#   'sector',
#   'adult',
#   'brand',
#   'time',
#   'year',
#   'see',
#   'industry'],
#  ['start',
#   'wolf',
#   'wajdan',
#   'market',
#   'rank',
#   'dubai',
#   'business',
#   'squat',
#   'time',
#   'location'],
#  ['start',
#   'wolf',
#   'wajdan',
#   'market',
#   'rank',
#   'dubai',
#   'business',
#   'squat',
#   'time',
#   'location'],
#  ['start',
#   'wolf',
#   'wajdan',
#   'market',
#   'rank',
#   'dubai',
#   'business',
#   'squat',
#   'time',
#   'location'],
#  ['decision',
#   'company',
#   'operator',
#   'london',
#   'passenger',
#   'supreme',
#   'ruling',
#   'uber',
#   'court',
#   'rideshare',
#   'book'],
#  ['customer',
#   'cryptocurrency',
#   'company',
#   'use',
#   'crypto',
#   'cryptocurrencies',
#   'cryptos',
#   'year',
#   'platform',
#   'payment'],
#  ['customer',
#   'cryptocurrency',
#   'company',
#   'use',
#   'crypto',
#   'cryptocurrencies',
#   'cryptos',
#   'year',
#   'platform',
#   'payment'],
#  ['customer',
#   'cryptocurrency',
#   'company',
#   'use',
#   'crypto',
#   'cryptocurrencies',
#   'cryptos',
#   'year',
#   'platform',
#   'payment'],
#  ['customer',
#   'cryptocurrency',
#   'company',
#   'use',
#   'crypto',
#   'cryptocurrencies',
#   'cryptos',
#   'year',
#   'platform',
#   'payment'],
#  ['europe',
#   'rate',
#   'growth',
#   'country',
#   'market',
#   'capital',
#   'innovation',
#   'export',
#   'region'],
#  ['europe',
#   'rate',
#   'growth',
#   'country',
#   'market',
#   'capital',
#   'innovation',
#   'export',
#   'region'],
#  ['europe',
#   'rate',
#   'growth',
#   'country',
#   'market',
#   'capital',
#   'innovation',
#   'export',
#   'region'],
#  ['app',
#   'company',
#   'date',
#   'metaverse',
#   'use',
#   'online',
#   'nyborg',
#   'tinder',
#   'offline'],
#  ['fan',
#   'token',
#   'bitcoin',
#   'crypto',
#   'football',
#   'david',
#   'club',
#   'become',
#   'make',
#   'relationship'],
#  ['fan',
#   'token',
#   'bitcoin',
#   'crypto',
#   'football',
#   'david',
#   'club',
#   'become',
#   'make',
#   'relationship'],
#  ['fan',
#   'token',
#   'bitcoin',
#   'crypto',
#   'football',
#   'david',
#   'club',
#   'become',
#   'make',
#   'relationship'],
#  ['company',
#   'twitter',
#   'technology',
#   'role',
#   'chairman',
#   'team',
#   'step',
#   'officer',
#   'ceo',
#   'dorsey',
#   'announce'],
#  ['bitcoin', 'market', 'drop', 'vaccine', 'mutation', 'resistant', 'cent'],
#  ['europe',
#   'tourism',
#   'travel',
#   'winter',
#   'market',
#   'santa',
#   'season',
#   'rovaniemi',
#   'business',
#   'tourist',
#   'year',
#   'course'],
#  ['europe',
#   'tourism',
#   'travel',
#   'winter',
#   'market',
#   'santa',
#   'season',
#   'rovaniemi',
#   'business',
#   'tourist',
#   'year',
#   'course'],
#  ['europe',
#   'tourism',
#   'travel',
#   'winter',
#   'market',
#   'santa',
#   'season',
#   'rovaniemi',
#   'business',
#   'tourist',
#   'year',
#   'course'],
#  ['company',
#   'advertising',
#   'instagram',
#   'continue',
#   'use',
#   'medium',
#   'facebook',
#   'lush',
#   'time',
#   'platform'],
#  ['company',
#   'advertising',
#   'instagram',
#   'continue',
#   'use',
#   'medium',
#   'facebook',
#   'lush',
#   'time',
#   'platform'],
#  ['create',
#   'company',
#   'world',
#   'plan',
#   'game',
#   'metaverse',
#   'call',
#   'build',
#   'omniverse',
#   'giant'],
#  ['create',
#   'company',
#   'world',
#   'plan',
#   'game',
#   'metaverse',
#   'call',
#   'build',
#   'omniverse',
#   'giant'],
#  ['create',
#   'company',
#   'world',
#   'plan',
#   'game',
#   'metaverse',
#   'call',
#   'build',
#   'omniverse',
#   'giant'],
#  ['create',
#   'company',
#   'world',
#   'plan',
#   'game',
#   'metaverse',
#   'call',
#   'build',
#   'omniverse',
#   'giant'],
#  ['create',
#   'company',
#   'world',
#   'plan',
#   'game',
#   'metaverse',
#   'call',
#   'build',
#   'omniverse',
#   'giant'],
#  ['aircraft',
#   'company',
#   'change',
#   'emission',
#   'europe',
#   'pipistrel',
#   'smes',
#   'business',
#   'commission',
#   'year',
#   'firm'],
#  ['company',
#   'publisher',
#   'content',
#   'france',
#   'google',
#   'tech',
#   'news',
#   'deal',
#   'law',
#   'license',
#   'year'],
#  ['lakers',
#   'crypto',
#   'center',
#   'sport',
#   'staple',
#   'com',
#   'year',
#   'win',
#   'king',
#   'name'],
#  ['challenge',
#   'change',
#   'need',
#   'finance',
#   'lot',
#   'sector',
#   'business',
#   'innovation'],
#  ['challenge',
#   'change',
#   'need',
#   'finance',
#   'lot',
#   'sector',
#   'business',
#   'innovation'],
#  ['challenge',
#   'change',
#   'need',
#   'finance',
#   'lot',
#   'sector',
#   'business',
#   'innovation'],
#  ['challenge',
#   'change',
#   'need',
#   'finance',
#   'lot',
#   'sector',
#   'business',
#   'innovation'],
#  ['consolidation',
#   'company',
#   'doordash',
#   'market',
#   'delivery',
#   'deal',
#   'food',
#   'acquisition',
#   'year',
#   'base',
#   'service'],
#  ['future', 'game', 'sport', 'blockchain', 'play', 'part', 'think', 'week'],
#  ['future', 'game', 'sport', 'blockchain', 'play', 'part', 'think', 'week'],
#  ['future', 'game', 'sport', 'blockchain', 'play', 'part', 'think', 'week'],
#  ['publisher', 'google', 'medium', 'spain', 'news', 'law', 'fee'],
#  ['video',
#   'idea',
#   'commissioner',
#   'people',
#   'innovation',
#   'lisbon',
#   'mood',
#   'invention'],
#  ['europe',
#   'farm',
#   'start',
#   'ups',
#   'fintech',
#   'chamber',
#   'commerce',
#   'kong',
#   'business'],
#  ['europe',
#   'farm',
#   'start',
#   'ups',
#   'fintech',
#   'chamber',
#   'commerce',
#   'kong',
#   'business'],
#  ['gouna',
#   'town',
#   'people',
#   'orascom',
#   'build',
#   'place',
#   'year',
#   'sea',
#   'work'],
#  ['cryptocurrency',
#   'month',
#   'trade',
#   'fund',
#   'exchange',
#   'launch',
#   'price',
#   'year'],
#  ['day',
#   'bitcoin',
#   'stock',
#   'fund',
#   'trade',
#   'exchange',
#   'investor',
#   'price',
#   'buy'],
#  ['day',
#   'bitcoin',
#   'stock',
#   'fund',
#   'trade',
#   'exchange',
#   'investor',
#   'price',
#   'buy'],
#  ['mpp',
#   'net',
#   'leader',
#   'carbon',
#   'plan',
#   'company',
#   'fuel',
#   'sector',
#   'zero',
#   'industry',
#   'steel'],
#  ['mpp',
#   'net',
#   'leader',
#   'carbon',
#   'plan',
#   'company',
#   'fuel',
#   'sector',
#   'zero',
#   'industry',
#   'steel'],
#  ['economy', 'world', 'uae', 'expo', 'event', 'year', 'driver', 'work'],
#  ['economy', 'world', 'uae', 'expo', 'event', 'year', 'driver', 'work'],
#  ['economy', 'world', 'uae', 'expo', 'event', 'year', 'driver', 'work'],
#  ['economy', 'world', 'uae', 'expo', 'event', 'year', 'driver', 'work'],
#  ['cryptocurrency',
#   'month',
#   'trade',
#   'fund',
#   'exchange',
#   'launch',
#   'price',
#   'year'],
#  ['verde',
#   'casa',
#   'europe',
#   'facility',
#   'use',
#   'investment',
#   'acecann',
#   'cannabis',
#   'industry'],
#  ['bay',
#   'company',
#   'texas',
#   'factory',
#   'musk',
#   'area',
#   'expand',
#   'california',
#   'tesla',
#   'headquarters',
#   'austin'],
#  ['turner', 'music', 'catalogue', 'stream', 'deal', 'tina', 'record', 'rock'],
#  ['turner', 'music', 'catalogue', 'stream', 'deal', 'tina', 'record', 'rock'],
#  ['material',
#   'economy',
#   'eisenach',
#   'production',
#   'area',
#   'people',
#   'business',
#   'month',
#   'plant',
#   'say'],
#  ['rate',
#   'tax',
#   'ireland',
#   'france',
#   'country',
#   'germany',
#   'increase',
#   'government',
#   'source'],
#  ['bernard', 'pay', 'minister', 'fraud', 'case', 'club', 'year', 'tapie'],
#  ['company',
#   'period',
#   'use',
#   'let',
#   'product',
#   'applicator',
#   'year',
#   'plastic'],
#  ['company',
#   'period',
#   'use',
#   'let',
#   'product',
#   'applicator',
#   'year',
#   'plastic'],
#  ['cheveau',
#   'wine',
#   'frost',
#   'manager',
#   'appellation',
#   'year',
#   'loss',
#   'hail'],
#  ['cheveau',
#   'wine',
#   'frost',
#   'manager',
#   'appellation',
#   'year',
#   'loss',
#   'hail'],
#  ['show',
#   'france',
#   'start',
#   'survey',
#   'ups',
#   'french',
#   'revenue',
#   'year',
#   'cent'],
#  ['show',
#   'france',
#   'start',
#   'survey',
#   'ups',
#   'french',
#   'revenue',
#   'year',
#   'cent'],
#  ['casino',
#   'tax',
#   'hall',
#   'ukraine',
#   'sector',
#   'market',
#   'government',
#   'year',
#   'work'],
#  ['casino',
#   'tax',
#   'hall',
#   'ukraine',
#   'sector',
#   'market',
#   'government',
#   'year',
#   'work'],
#  ['interest',
#   'statement',
#   'report',
#   'group',
#   'bond',
#   'debt',
#   'estate',
#   'payment'],
#  ['emission',
#   'gas',
#   'climate',
#   'world',
#   'china',
#   'effort',
#   'country',
#   'coal',
#   'relation',
#   'cooperation',
#   'greenhouse',
#   'power',
#   'cent'],
#  ['company',
#   'economy',
#   'world',
#   'country',
#   'investment',
#   'park',
#   'delivery',
#   'product',
#   'business',
#   'businessmen',
#   'resident'],
#  ['economy',
#   'tax',
#   'loan',
#   'currency',
#   'country',
#   'investment',
#   'event',
#   'business',
#   'export',
#   'land'],
#  ['system',
#   'company',
#   'technology',
#   'pledge',
#   'game',
#   'use',
#   'patent',
#   'people',
#   'player'],
#  ['system',
#   'company',
#   'technology',
#   'pledge',
#   'game',
#   'use',
#   'patent',
#   'people',
#   'player'],
#  ['fan',
#   'company',
#   'pay',
#   'content',
#   'space',
#   'creator',
#   'policy',
#   'onlyfans',
#   'celebrity'],
#  ['minister',
#   'country',
#   'sector',
#   'school',
#   'education',
#   'government',
#   'sama',
#   'digital'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['technology',
#   'company',
#   'opportunity',
#   'redzinc',
#   'result',
#   'investor',
#   'business',
#   'platform',
#   'get'],
#  ['company',
#   'economy',
#   'president',
#   'multinationals',
#   'summit',
#   'country',
#   'cooperation',
#   'event',
#   'city',
#   'industry'],
#  ['company',
#   'economy',
#   'president',
#   'multinationals',
#   'summit',
#   'country',
#   'cooperation',
#   'event',
#   'city',
#   'industry'],
#  ['reform',
#   'bank',
#   'begin',
#   'school',
#   'privatization',
#   'road',
#   'business',
#   'year',
#   'state'],
#  ['employee',
#   'economy',
#   'thing',
#   'home',
#   'country',
#   'people',
#   'job',
#   'gig',
#   'work'],
#  ['employee',
#   'economy',
#   'thing',
#   'home',
#   'country',
#   'people',
#   'job',
#   'gig',
#   'work'],
#  ['employee',
#   'economy',
#   'thing',
#   'home',
#   'country',
#   'people',
#   'job',
#   'gig',
#   'work'],
#  ['customer',
#   'interaction',
#   'user',
#   'bot',
#   'chatbot',
#   'research',
#   'service',
#   'study'],
#  ['customer',
#   'interaction',
#   'user',
#   'bot',
#   'chatbot',
#   'research',
#   'service',
#   'study'],
#  ['change',
#   'emission',
#   'world',
#   'climate',
#   'gas',
#   'china',
#   'country',
#   'america',
#   'greenhouse'],
#  ['jerry',
#   'decision',
#   'company',
#   'west',
#   'call',
#   'bank',
#   'cream',
#   'ben',
#   'settlement'],
#  ['azuki', 'lot', 'home', 'rise', 'dubai', 'brand', 'business', 'year'],
#  ['azuki', 'lot', 'home', 'rise', 'dubai', 'brand', 'business', 'year'],
#  ['azuki', 'lot', 'home', 'rise', 'dubai', 'brand', 'business', 'year'],
#  ['azuki', 'lot', 'home', 'rise', 'dubai', 'brand', 'business', 'year'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['factory',
#   'tariff',
#   'france',
#   'bicycle',
#   'asia',
#   'dump',
#   'industry',
#   'work'],
#  ['offer',
#   'company',
#   'entrepreneur',
#   'opportunity',
#   'healthcare',
#   'medium',
#   'dubai',
#   'business',
#   'incubator',
#   'startup',
#   'city'],
#  ['graduate',
#   'leadership',
#   'opportunity',
#   'diversity',
#   'experience',
#   'growth',
#   'gemba',
#   'business',
#   'student',
#   'say'],
#  ['graduate',
#   'leadership',
#   'opportunity',
#   'diversity',
#   'experience',
#   'growth',
#   'gemba',
#   'business',
#   'student',
#   'say'],
#  ['graduate',
#   'leadership',
#   'opportunity',
#   'diversity',
#   'experience',
#   'growth',
#   'gemba',
#   'business',
#   'student',
#   'say'],
#  ['graduate',
#   'leadership',
#   'opportunity',
#   'diversity',
#   'experience',
#   'growth',
#   'gemba',
#   'business',
#   'student',
#   'say'],
#  ['supply', 'abu', 'al', 'world', 'port', 'dhabi', 'maritime', 'part'],
#  ['supply', 'abu', 'al', 'world', 'port', 'dhabi', 'maritime', 'part'],
#  ['change', 'mellon', 'people', 'money', 'bit', 'something'],
#  ['offer',
#   'company',
#   'entrepreneur',
#   'opportunity',
#   'healthcare',
#   'medium',
#   'dubai',
#   'business',
#   'incubator',
#   'startup',
#   'city'],
#  ['thing', 'people', 'jo', 'business', 'wax', 'year', 'kitchen'],
#  ['thing', 'people', 'jo', 'business', 'wax', 'year', 'kitchen'],
#  ['app', 'company', 'technology', 'review', 'china', 'data', 'didi'],
#  ['technology',
#   'imagine',
#   'form',
#   'healthcare',
#   'product',
#   'dubai',
#   'group',
#   'covid',
#   'try',
#   'place',
#   'surgery'],
#  ['charge',
#   'company',
#   'trump',
#   'office',
#   'tax',
#   'investigation',
#   'apartment',
#   'york',
#   'business',
#   'organization'],
#  ['company',
#   'issue',
#   'people',
#   'brand',
#   'consumer',
#   'product',
#   'business',
#   'year',
#   'see'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['company',
#   'europe',
#   'garden',
#   'network',
#   'eva',
#   'fund',
#   'help',
#   'business',
#   'bill',
#   'year'],
#  ['future',
#   'technology',
#   'shopping',
#   'client',
#   'experience',
#   'online',
#   'shop',
#   'cannes',
#   'changemakers',
#   'series',
#   'think'],
#  ['poison',
#   'rat',
#   'fad',
#   'cryptocurrencies',
#   'class',
#   'survey',
#   'investor',
#   'trading',
#   'cent'],
#  ['company',
#   'thought',
#   'williams',
#   'diversity',
#   'way',
#   'product',
#   'series',
#   'euronews'],
#  ['tell',
#   'regulation',
#   'europe',
#   'point',
#   'view',
#   'france',
#   'tech',
#   'euronews'],
#  ['tell',
#   'regulation',
#   'europe',
#   'point',
#   'view',
#   'france',
#   'tech',
#   'euronews'],
#  ['day',
#   'ceo',
#   'vivatech',
#   'include',
#   'speech',
#   'cest',
#   'conference',
#   'june',
#   'startup'],
#  ['destroy',
#   'house',
#   'port',
#   'space',
#   'explosion',
#   'hotel',
#   'guesthouse',
#   'antoine',
#   'business',
#   'beyt',
#   'beirut'],
#  ['dma',
#   'regulator',
#   'minister',
#   'gatekeeper',
#   'country',
#   'lawmaker',
#   'target',
#   'allow',
#   'commission',
#   'acquisition',
#   'draft',
#   'rule'],
#  ['hub',
#   'set',
#   'start',
#   'ups',
#   'success',
#   'help',
#   'dubai',
#   'business',
#   'story',
#   'year',
#   'cent'],
#  ['emission', 'polluter', 'con', 'report', 'zero', 'policy', 'carbon'],
#  ['switzerland',
#   'hold',
#   'scale',
#   'investor',
#   'forum',
#   'event',
#   'june',
#   'putin',
#   'talk'],
#  ['address',
#   'plan',
#   'gelsinger',
#   'shortage',
#   'world',
#   'take',
#   'semiconductor',
#   'intel',
#   'year',
#   'industry',
#   'chip'],
#  ['company',
#   'europe',
#   'recovery',
#   'world',
#   'economy',
#   'eu',
#   'investment',
#   'money',
#   'transition',
#   'work'],
#  ['company',
#   'europe',
#   'recovery',
#   'world',
#   'economy',
#   'eu',
#   'investment',
#   'money',
#   'transition',
#   'work'],
#  ['company',
#   'europe',
#   'recovery',
#   'world',
#   'economy',
#   'eu',
#   'investment',
#   'money',
#   'transition',
#   'work'],
#  ['company',
#   'europe',
#   'recovery',
#   'world',
#   'economy',
#   'eu',
#   'investment',
#   'money',
#   'transition',
#   'work'],
#  ['shareholder',
#   'paris',
#   'travel',
#   'passenger',
#   'agreement',
#   'train',
#   'bank',
#   'statement',
#   'increase',
#   'eurostar',
#   'service',
#   'state'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['company',
#   'woman',
#   'entrepreneur',
#   'need',
#   'europe',
#   'business',
#   'serena',
#   'face'],
#  ['supply',
#   'technology',
#   'production',
#   'manufacturing',
#   'semiconductor',
#   'shortage',
#   'year',
#   'chip'],
#  ['supply',
#   'technology',
#   'production',
#   'manufacturing',
#   'semiconductor',
#   'shortage',
#   'year',
#   'chip'],
#  ['supply',
#   'technology',
#   'production',
#   'manufacturing',
#   'semiconductor',
#   'shortage',
#   'year',
#   'chip'],
#  ['supply',
#   'technology',
#   'production',
#   'manufacturing',
#   'semiconductor',
#   'shortage',
#   'year',
#   'chip'],
#  ['company',
#   'remote',
#   'shift',
#   'point',
#   'hiramatsu',
#   'benefit',
#   'result',
#   'life',
#   'covid',
#   'location',
#   'work'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['company',
#   'europe',
#   'technology',
#   'transformation',
#   'economy',
#   'business',
#   'policy',
#   'development'],
#  ['europe',
#   'eu',
#   'investment',
#   'market',
#   'semiconductor',
#   'product',
#   'bloc',
#   'commission',
#   'alliance',
#   'strategy',
#   'industry'],
#  ['company',
#   'aid',
#   'market',
#   'commission',
#   'non',
#   'year',
#   'subsidy',
#   'competition',
#   'state'],
#  ['technology',
#   'economy',
#   'need',
#   'end',
#   'dubai',
#   'government',
#   'business',
#   'support',
#   'industry'],
#  ['technology',
#   'economy',
#   'need',
#   'end',
#   'dubai',
#   'government',
#   'business',
#   'support',
#   'industry'],
#  ['technology',
#   'economy',
#   'need',
#   'end',
#   'dubai',
#   'government',
#   'business',
#   'support',
#   'industry'],
#  ['technology',
#   'economy',
#   'need',
#   'end',
#   'dubai',
#   'government',
#   'business',
#   'support',
#   'industry'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['habitec',
#   'eucalyptus',
#   'furniture',
#   'angola',
#   'tree',
#   'explain',
#   'use',
#   'sector',
#   'school',
#   'help',
#   'product',
#   'resource'],
#  ['mother', 'family', 'farm', 'sweet', 'business', 'dulce', 'kamarta'],
#  ['mother', 'family', 'farm', 'sweet', 'business', 'dulce', 'kamarta'],
#  ['mother', 'family', 'farm', 'sweet', 'business', 'dulce', 'kamarta'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['employee',
#   'company',
#   'technology',
#   'office',
#   'home',
#   'people',
#   'business',
#   'year',
#   'make',
#   'work'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['emission',
#   'farm',
#   'use',
#   'feed',
#   'market',
#   'year',
#   'methane',
#   'hafner',
#   'carbon',
#   'cent'],
#  ['charge',
#   'trial',
#   'right',
#   'monday',
#   'weinstein',
#   'court',
#   'rape',
#   'criminal',
#   'lawyer',
#   'state'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['project',
#   'user',
#   'idea',
#   'fashion',
#   'ucqc',
#   'clothes',
#   'business',
#   'wheelchair'],
#  ['future',
#   'change',
#   'projection',
#   'user',
#   'need',
#   'climate',
#   'tool',
#   'data',
#   'help',
#   'information',
#   'city'],
#  ['future',
#   'change',
#   'projection',
#   'user',
#   'need',
#   'climate',
#   'tool',
#   'data',
#   'help',
#   'information',
#   'city'],
#  ['future',
#   'change',
#   'projection',
#   'user',
#   'need',
#   'climate',
#   'tool',
#   'data',
#   'help',
#   'information',
#   'city'],
#  ['future',
#   'change',
#   'projection',
#   'user',
#   'need',
#   'climate',
#   'tool',
#   'data',
#   'help',
#   'information',
#   'city'],
#  ['future',
#   'change',
#   'projection',
#   'user',
#   'need',
#   'climate',
#   'tool',
#   'data',
#   'help',
#   'information',
#   'city'],
#  ['pass', 'gust', 'wind', 'container', 'ship', 'trade', 'affect', 'cause'],
#  ['flight',
#   'world',
#   'passenger',
#   'country',
#   'airline',
#   'story',
#   'see',
#   'euronews'],
#  ['enjoy',
#   'thing',
#   'sport',
#   'lot',
#   'country',
#   'people',
#   'outdoors',
#   'business',
#   'work'],
#  ['enjoy',
#   'thing',
#   'sport',
#   'lot',
#   'country',
#   'people',
#   'outdoors',
#   'business',
#   'work'],
#  ['enjoy',
#   'thing',
#   'sport',
#   'lot',
#   'country',
#   'people',
#   'outdoors',
#   'business',
#   'work'],
#  ['enjoy',
#   'thing',
#   'sport',
#   'lot',
#   'country',
#   'people',
#   'outdoors',
#   'business',
#   'work'],
#  ['measure', 'company', 'fuel', 'vehicle', 'market', 'year', 'ski', 'work'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['company',
#   'connect',
#   'help',
#   'business',
#   'cluster',
#   'pharmacy',
#   'patient',
#   'member',
#   'medicine',
#   'mol'],
#  ['vote',
#   'senate',
#   'tax',
#   'priority',
#   'house',
#   'gop',
#   'party',
#   'bill',
#   'year'],
#  ['aircraft', 'tell', 'dassault', 'probe', 'love', 'france', 'afp', 'source'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['company',
#   'climate',
#   'effort',
#   'market',
#   'cdp',
#   'event',
#   'euronews',
#   'city'],
#  ['right',
#   'repair',
#   'spare',
#   'appliance',
#   'device',
#   'fix',
#   'part',
#   'year',
#   'break'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['company',
#   'factory',
#   'eu',
#   'bki',
#   'coffee',
#   'help',
#   'business',
#   'case',
#   'industry',
#   'transition'],
#  ['foot', 'leader', 'thing', 'way', 'tomorrow', 'today', 'business'],
#  ['foot', 'leader', 'thing', 'way', 'tomorrow', 'today', 'business'],
#  ['foot', 'leader', 'thing', 'way', 'tomorrow', 'today', 'business'],
#  ['foot', 'leader', 'thing', 'way', 'tomorrow', 'today', 'business'],
#  ['company',
#   'privacy',
#   'survey',
#   'people',
#   'data',
#   'report',
#   'organisation',
#   'robert',
#   'security',
#   'cisco',
#   'pandemic'],
#  ['company',
#   'startup',
#   'investment',
#   'footprint',
#   'fund',
#   'help',
#   'venture',
#   'capital',
#   'coalition',
#   'money'],
#  ['croatia', 'visa', 'country', 'term', 'worker', 'year'],
#  ['croatia', 'visa', 'country', 'term', 'worker', 'year'],
#  ['croatia', 'visa', 'country', 'term', 'worker', 'year'],
#  ['croatia', 'visa', 'country', 'term', 'worker', 'year'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['company',
#   'europe',
#   'climate',
#   'chairman',
#   'deal',
#   'business',
#   'executive',
#   'industry',
#   'carbon'],
#  ['economy',
#   'recovery',
#   'forecast',
#   'growth',
#   'risk',
#   'eurozone',
#   'year',
#   'cent'],
#  ['privatisation',
#   'plan',
#   'mirziyoyev',
#   'bank',
#   'investment',
#   'enterprise',
#   'investor',
#   'year',
#   'make',
#   'state'],
#  ['privatisation',
#   'plan',
#   'mirziyoyev',
#   'bank',
#   'investment',
#   'enterprise',
#   'investor',
#   'year',
#   'make',
#   'state'],
#  ['privatisation',
#   'plan',
#   'mirziyoyev',
#   'bank',
#   'investment',
#   'enterprise',
#   'investor',
#   'year',
#   'make',
#   'state'],
#  ['company',
#   'europe',
#   'railway',
#   'government',
#   'business',
#   'support',
#   'eurostar'],
#  ['sentence',
#   'president',
#   'country',
#   'term',
#   'park',
#   'court',
#   'business',
#   'south',
#   'prison',
#   'year',
#   'lee'],
#  ['ceiling',
#   'glass',
#   'company',
#   'tell',
#   'world',
#   'coal',
#   'chemical',
#   'energy',
#   'business',
#   'live',
#   'solvay',
#   'industry'],
#  ['ceiling',
#   'glass',
#   'company',
#   'tell',
#   'world',
#   'coal',
#   'chemical',
#   'energy',
#   'business',
#   'live',
#   'solvay',
#   'industry'],
#  ['bedminster',
#   'trump',
#   'president',
#   'golf',
#   'game',
#   'america',
#   'championship',
#   'event',
#   'pga',
#   'course'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['helpdesk', 'company', 'property', 'china', 'market', 'protect', 'sme'],
#  ['company', 'woman', 'board', 'list', 'executive', 'member', 'cent'],
#  ['dog', 'pet', 'treat', 'theft', 'crime', 'female', 'thief'],
#  ['passenger',
#   'travel',
#   'ban',
#   'country',
#   'airline',
#   'britain',
#   'test',
#   'virus',
#   'coronavirus'],
#  ['change',
#   'import',
#   'need',
#   'eu',
#   'tariff',
#   'trade',
#   'deal',
#   'business',
#   'custom',
#   'rule'],
#  ['company',
#   'europe',
#   'recovery',
#   'economy',
#   'country',
#   'market',
#   'business',
#   'year'],
#  ['company',
#   'europe',
#   'recovery',
#   'economy',
#   'country',
#   'market',
#   'business',
#   'year'],
#  ['company',
#   'europe',
#   'recovery',
#   'economy',
#   'country',
#   'market',
#   'business',
#   'year'],
#  ['company',
#   'europe',
#   'recovery',
#   'economy',
#   'country',
#   'market',
#   'business',
#   'year'],
#  ['company',
#   'europe',
#   'recovery',
#   'economy',
#   'country',
#   'market',
#   'business',
#   'year'],
#  ['dog', 'pet', 'treat', 'theft', 'crime', 'female', 'thief'],
#  ['alejandro',
#   'founder',
#   'people',
#   'fund',
#   'recommendation',
#   'serrano',
#   'base',
#   'gritti'],
#  ['recovery', 'opportunity', 'relation', 'direction', 'euronews'],
#  ['matt', 'samra', 'brussels', 'lot', 'medium', 'business', 'buddy', 'butter'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['europe',
#   'economy',
#   'sector',
#   'term',
#   'report',
#   'consumer',
#   'business',
#   'export'],
#  ['measure',
#   'technology',
#   'cutter',
#   'mr',
#   'hammick',
#   'huntsman',
#   'carnera',
#   'son',
#   'image',
#   'robot',
#   'year'],
#  ['economy', 'fashion', 'report', 'dubai', 'food', 'muslim', 'state'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['company',
#   'entrepreneur',
#   'portail',
#   'souffle',
#   'du',
#   'rebond',
#   'association',
#   'bounce',
#   'difficulty'],
#  ['turnover', 'number', 'celebration', 'christmas', 'france', 'year'],
#  ['change',
#   'need',
#   'twelve',
#   'people',
#   'help',
#   'brand',
#   'business',
#   'kind',
#   'make',
#   'work'],
#  ['change',
#   'need',
#   'twelve',
#   'people',
#   'help',
#   'brand',
#   'business',
#   'kind',
#   'make',
#   'work'],
#  ['shop', 'people', 'generation', 'money', 'shopper', 'second'],
#  ['employee',
#   'company',
#   'video',
#   'travel',
#   'way',
#   'work',
# ...
#  ['offer',
#   'create',
#   'company',
#   'europe',
#   'economy',
#   'space',
#   'people',
#   'programme',
#   'develop',
#   'service'],
#  ['offer',
#   'create',
#   'company',
#   'europe',
#   'economy',
#   'space',
#   'people',
#   'programme',
#   'develop',
#   'service'],
#  ['offer',
#   'create',
#   'company',
#   'europe',
#   'economy',
#   'space',
#   'people',
#   'programme',
#   'develop',
#   'service'],
#  ['plant',
#   'climate',
#   'grow',
#   'tregothnan',
#   'estate',
#   'year',
#   'tea',
#   'produce',
#   'get'],
#  ['plant',
#   'climate',
#   'grow',
#   'tregothnan',
#   'estate',
#   'year',
#   'tea',
#   'produce',
#   'get'],
#  ['plant',
#   'climate',
#   'grow',
#   'tregothnan',
#   'estate',
#   'year',
#   'tea',
#   'produce',
#   'get'],
#  ['plant',
#   'climate',
#   'grow',
#   'tregothnan',
#   'estate',
#   'year',
#   'tea',
#   'produce',
#   'get'],
#  ['plant',
#   'climate',
#   'grow',
#   'tregothnan',
#   'estate',
#   'year',
#   'tea',
#   'produce',
#   'get'],
#  ['defence', 'barracuda', 'class', 'france', 'group', 'macron', 'submarine'],
#  ['company',
#   'easyjet',
#   'union',
#   'strike',
#   'agreement',
#   'statement',
#   'aviation',
#   'service',
#   'stobart',
#   'airport'],
#  ['vote',
#   'assessment',
#   'opposition',
#   'eu',
#   'ireland',
#   'trade',
#   'government',
#   'south',
#   'mercosur',
#   'parliament',
#   'member',
#   'draft'],
#  ['look', 'farm', 'sector', 'deal', 'export', 'event', 'absolute'],
#  ['max', 'september', 'end', 'fly', 'price', 'say'],
#  ['interest', 'rate', 'need', 'tenreyro', 'deal', 'boe', 'britain'],
#  ['company',
#   'tax',
#   'tariff',
#   'france',
#   'investigation',
#   'dispute',
#   'tech',
#   'trade',
#   'law'],
#  ['look', 'farm', 'sector', 'deal', 'export', 'event', 'absolute'],
#  ['leader',
#   'company',
#   'technology',
#   'salesforce',
#   'brexit',
#   'tech',
#   'people',
#   'term',
#   'britain',
#   'business'],
#  ['carney',
#   'england',
#   'france',
#   'bank',
#   'concern',
#   'governor',
#   'mark',
#   'support',
#   'move',
#   'imf',
#   'source'],
#  ['buzyn', 'drug', 'france', 'people', 'boiron'],
#  ['immigration', 'plan', 'brexit', 'survey', 'worker', 'threshold', 'month'],
#  ['centre',
#   'qingdao',
#   'management',
#   'zone',
#   'business',
#   'forum',
#   'wealth',
#   'year',
#   'industry',
#   'development'],
#  ['centre',
#   'qingdao',
#   'management',
#   'zone',
#   'business',
#   'forum',
#   'wealth',
#   'year',
#   'industry',
#   'development'],
#  ['centre',
#   'qingdao',
#   'management',
#   'zone',
#   'business',
#   'forum',
#   'wealth',
#   'year',
#   'industry',
#   'development'],
#  ['company',
#   'economy',
#   'deloitte',
#   'risk',
#   'brexit',
#   'survey',
#   'investment',
#   'crisis',
#   'business',
#   'britain'],
#  ['euro', 'equity', 'bank', 'investment', 'agree', 'job', 'deutsche'],
#  ['change', 'economy', 'way', 'investor', 'startup', 'transition'],
#  ['change', 'economy', 'way', 'investor', 'startup', 'transition'],
#  ['change', 'economy', 'way', 'investor', 'startup', 'transition'],
#  ['change', 'economy', 'way', 'investor', 'startup', 'transition'],
#  ['world', 'qingdao', 'conference', 'trade', 'build', 'city'],
#  ['world', 'qingdao', 'conference', 'trade', 'build', 'city'],
#  ['world', 'qingdao', 'conference', 'trade', 'build', 'city'],
#  ['company',
#   'brexit',
#   'trade',
#   'deal',
#   'ntt',
#   'britain',
#   'government',
#   'time',
#   'impact'],
#  ['sorrell',
#   'advertising',
#   'world',
#   'data',
#   'market',
#   'hop',
#   'delivers',
#   'describe',
#   'entirety',
#   'approach'],
#  ['juncker', 'union', 'trade', 'deal', 'reach', 'south'],
#  ['union',
#   'president',
#   'exception',
#   'summit',
#   'agreement',
#   'accord',
#   'end',
#   'nation',
#   'mercosur',
#   'g20'],
#  ['company', 'economy', 'tourism', 'smes', 'kid', 'city', 'say'],
#  ['company', 'economy', 'tourism', 'smes', 'kid', 'city', 'say'],
#  ['company', 'economy', 'tourism', 'smes', 'kid', 'city', 'say'],
#  ['stone', 'europe', 'company', 'belarus', 'china', 'park'],
#  ['flight',
#   'aircraft',
#   'missile',
#   'shoot',
#   'area',
#   'airline',
#   'airspace',
#   'carrier',
#   'fly',
#   'iran',
#   'order'],
#  ['system', 'extradition', 'people', 'government', 'protester', 'bill', 'lam'],
#  ['decision',
#   'apply',
#   'union',
#   'stripe',
#   'mark',
#   'trademark',
#   'court',
#   'product',
#   'rule'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['joint', 'bio', 'product', 'research', 'base', 'industry'],
#  ['europe', 'bbi', 'part', 'bio', 'base', 'research', 'joint', 'industry'],
#  ['change',
#   'gas',
#   'climate',
#   'country',
#   'meet',
#   'statement',
#   'target',
#   'government',
#   'britain',
#   'carbon'],
#  ['bolt', 'market', 'uber', 'month', 'promise', 'cut', 'service', 'driver'],
#  ['change',
#   'meal',
#   'way',
#   'fascinating',
#   'food',
#   'business',
#   'post',
#   'week',
#   'huffington',
#   'source'],
#  ['change',
#   'meal',
#   'way',
#   'fascinating',
#   'food',
#   'business',
#   'post',
#   'week',
#   'huffington',
#   'source'],
#  ['change',
#   'meal',
#   'way',
#   'fascinating',
#   'food',
#   'business',
#   'post',
#   'week',
#   'huffington',
#   'source'],
#  ['change',
#   'meal',
#   'way',
#   'fascinating',
#   'food',
#   'business',
#   'post',
#   'week',
#   'huffington',
#   'source'],
#  ['woman',
#   'sport',
#   'statement',
#   'report',
#   'rap',
#   'campaign',
#   'press',
#   'month',
#   'neymar',
#   'accusation'],
#  ['chom', 'logger', 'patrol', 'people', 'come', 'income', 'cut', 'penh'],
#  ['chom', 'logger', 'patrol', 'people', 'come', 'income', 'cut', 'penh'],
#  ['company',
#   'board',
#   'chrysler',
#   'fiat',
#   'france',
#   'renault',
#   'government',
#   'merger',
#   'talk'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'support',
#   'service'],
#  ['company',
#   'sport',
#   'medium',
#   'brand',
#   'magazine',
#   'time',
#   'illustrate',
#   'meredith',
#   'print'],
#  ['company',
#   'plan',
#   'carmaker',
#   'fiat',
#   'deal',
#   'group',
#   'merger',
#   'talk',
#   'fca'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['company',
#   'europe',
#   'last2ticket',
#   'need',
#   'network',
#   'enterprise',
#   'help',
#   'business',
#   'time',
#   'event',
#   'service'],
#  ['day',
#   'leader',
#   'tournament',
#   'trump',
#   'president',
#   'trade',
#   'japan',
#   'abe',
#   'official',
#   'state'],
#  ['cuba',
#   'president',
#   'havana',
#   'analytics',
#   'people',
#   'data',
#   'dubai',
#   'business',
#   'oil'],
#  ['victory',
#   'congress',
#   'election',
#   'party',
#   'bjp',
#   'india',
#   'delhi',
#   'majority',
#   'modi'],
#  ['union',
#   'british',
#   'stace',
#   'brexit',
#   'collapse',
#   'government',
#   'firm',
#   'steel'],
#  ['edition',
#   'entrepreneur',
#   'tip',
#   'change',
#   'career',
#   'pastry',
#   'inspire',
#   'sustain',
#   'business'],
#  ['flight',
#   'max',
#   'change',
#   'training',
#   'spokesman',
#   'kill',
#   'software',
#   'time',
#   'jet',
#   'fatal'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['company',
#   'technology',
#   'use',
#   'market',
#   'help',
#   'product',
#   'innovation',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['project',
#   'centre',
#   'use',
#   'activity',
#   'market',
#   'organisation',
#   'product',
#   'support',
#   'cluster',
#   'research',
#   'member',
#   'development'],
#  ['episode',
#   'tradition',
#   'fight',
#   'gear',
#   'mozambique',
#   'inspire',
#   'awareness',
#   'health',
#   'africa',
#   'stay'],
#  ['company',
#   'conference',
#   'trade',
#   'terror',
#   'regime',
#   'organise',
#   'intelligence',
#   'iran',
#   'oil',
#   'year'],
#  ['economy',
#   'port',
#   'investment',
#   'country',
#   'benguela',
#   'business',
#   'airport',
#   'region'],
#  ['barrel',
#   'tariff',
#   'china',
#   'optimism',
#   'trade',
#   'rise',
#   'deal',
#   'oil',
#   'percent',
#   'cent'],
#  ['air',
#   'controller',
#   'fire',
#   'signal',
#   'head',
#   'crew',
#   'accord',
#   'timeline',
#   'land',
#   'communication',
#   'plane',
#   'emergency'],
#  ['juncker',
#   'recognition',
#   'europe',
#   'change',
#   'president',
#   'award',
#   'winner',
#   'recognise',
#   'business',
#   'commission',
#   'year'],
#  ['day',
#   'drc',
#   'company',
#   'corridor',
#   'use',
#   'border',
#   'port',
#   'train',
#   'angolan',
#   'railway',
#   'province',
#   'industry'],
#  ['rate',
#   'earnings',
#   'dollar',
#   'growth',
#   'expectation',
#   'data',
#   'market',
#   'fund',
#   'investor',
#   'year',
#   'inflation',
#   'percent'],
#  ['juncker',
#   'union',
#   'eu',
#   'justice',
#   'poland',
#   'country',
#   'election',
#   'party',
#   'pi',
#   'law',
#   'commission'],
#  ['project',
#   'president',
#   'share',
#   'china',
#   'principle',
#   'silk',
#   'road',
#   'forum',
#   'belt',
#   'say',
#   'initiative'],
#  ['go', 'space', 'lynx', 'people', 'trade', 'minute', 'brand', 'digital'],
#  ['flight',
#   'annamatz',
#   'tell',
#   'strike',
#   'passenger',
#   'pilot',
#   'airline',
#   'wage',
#   'reach',
#   'sa',
#   'talk',
#   'percent'],
#  ['tata', 'fire', 'need', 'concern', 'explosion', 'worker', 'plant', 'talbot'],
#  ['rugby',
#   'sport',
#   'arsenal',
#   'mike',
#   'people',
#   'school',
#   'level',
#   'football',
#   'academy',
#   'team'],
#  ['company',
#   'monday',
#   'misconduct',
#   'ghosn',
#   'tokyo',
#   'file',
#   'breach',
#   'trust'],
#  ['company', 'space', 'result', 'capsule', 'test', 'soil', 'spacex'],
#  ['air',
#   'aircraft',
#   'defence',
#   'fighter',
#   'japan',
#   'force',
#   'industry',
#   'say'],
#  ['flight',
#   'fire',
#   'kenya',
#   'evacuate',
#   'incident',
#   'airline',
#   'staff',
#   'kaa',
#   'authority',
#   'airport'],
#  ['company',
#   'attack',
#   'timeframe',
#   'minister',
#   'medium',
#   'facebook',
#   'legislation',
#   'law',
#   'gunman'],
#  ['philpott',
#   'tell',
#   'raybould',
#   'minister',
#   'election',
#   'party',
#   'crisis',
#   'wilson',
#   'trudeau',
#   'october'],
#  ['charge', 'trial', 'link', 'election', 'court', 'money', 'delay', 'state'],
#  ['emmanuel',
#   'union',
#   'president',
#   'election',
#   'macron',
#   'campaign',
#   'cabinet',
#   'loiseau'],
#  ['company',
#   'attack',
#   'timeframe',
#   'minister',
#   'medium',
#   'facebook',
#   'legislation',
#   'law',
#   'gunman'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['project',
#   'reporter',
#   'savarani',
#   'market',
#   'help',
#   'business',
#   'support',
#   'year',
#   'euronews'],
#  ['van',
#   'change',
#   'entrepreneur',
#   'zyl',
#   'world',
#   'impact',
#   'founder',
#   'people',
#   'membership',
#   'event',
#   'capital',
#   'club',
#   'member',
#   'conduit'],
#  ['van',
#   'change',
#   'entrepreneur',
#   'zyl',
#   'world',
#   'impact',
#   'founder',
#   'people',
#   'membership',
#   'event',
#   'capital',
#   'club',
#   'member',
#   'conduit'],
#  ['van',
#   'change',
#   'entrepreneur',
#   'zyl',
#   'world',
#   'impact',
#   'founder',
#   'people',
#   'membership',
#   'event',
#   'capital',
#   'club',
#   'member',
#   'conduit'],
#  ['world',
#   'people',
#   'market',
#   'vehicle',
#   'dubai',
#   'estate',
#   'tesla',
#   'year',
#   'district',
#   'model'],
#  ['world',
#   'people',
#   'market',
#   'vehicle',
#   'dubai',
#   'estate',
#   'tesla',
#   'year',
#   'district',
#   'model'],
#  ['world',
#   'people',
#   'market',
#   'vehicle',
#   'dubai',
#   'estate',
#   'tesla',
#   'year',
#   'district',
#   'model'],
#  ['company', 'tell', 'war', 'family', 'use', 'labourer', 'report', 'son'],
#  ['show',
#   'rate',
#   'pwc',
#   'survey',
#   'britain',
#   'service',
#   'fall',
#   'poll',
#   'firm'],
#  ['company',
#   'luanda',
#   'angola',
#   'webcor',
#   'investment',
#   'investor',
#   'cost',
#   'oil',
#   'repatriate'],
#  ['trial',
#   'company',
#   'jury',
#   'liability',
#   'phase',
#   'damage',
#   'bayer',
#   'court',
#   'case',
#   'cancer',
#   'cause',
#   'roundup'],
#  ...]

# %%
import csv

with open('CyberCrimeArticles-3.csv','r',encoding='utf-8') as csvinput:
    with open('week5.csv', 'w',encoding='utf-8') as csvoutput:
        writer = csv.writer(csvoutput, lineterminator='\n')
        reader = csv.reader(csvinput)

        everything = []
        row = next(reader)
        row.append('Keywords')
        everything.append(row)

        for row, el in zip(reader, topRel):
            row.append(el)
            everything.append(row)

        writer.writerows(everything)
